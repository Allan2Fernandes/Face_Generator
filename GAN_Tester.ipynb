# %%
import matplotlib
import tensorflow as tf
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
base_path = "Saved_models"
model_names = os.listdir(base_path)

# %%
model_paths = []
for model_name in model_names:
    path = os.path.join(base_path, model_name)
    model_paths.append(path)
    pass

# %%
models = []
for path in model_paths:
    model = tf.keras.models.load_model(path)
    models.append(model)
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
def display_image(image_array):
    image_array = image_array*0.5 + 0.5
    plt.imshow(image_array)
    plt.show()

# %%
for model, model_name in zip(models, model_names):
    generator, discriminator = model.layers
    prediction = 0
    generated_image = None
    while prediction < 0.7:
        noise = tf.random.normal(shape=(1, 128))
        generated_image = generator(noise)
        #display_image(generated_image[0])
        prediction = discriminator(generated_image)
        #print(prediction)
        pass
    print("Model: {}".format(model_name))
    print("Prediction certainty = {0:f}%".format(tf.get_static_value(prediction[0][0]*100)))
    display_image(generated_image[0])
# Out:
# Model: ModelEpoch10
# Prediction certainty = 73.210106%
# Model: ModelEpoch100
# Prediction certainty = 97.935776%
# Model: ModelEpoch15
# Prediction certainty = 82.341263%
# Model: ModelEpoch20
# Prediction certainty = 80.857979%
# Model: ModelEpoch25
# Prediction certainty = 80.197983%
# Model: ModelEpoch30
# Prediction certainty = 70.758324%
# Model: ModelEpoch35
# Prediction certainty = 73.867401%
# Model: ModelEpoch40
# Prediction certainty = 79.196510%
# Model: ModelEpoch45
# Prediction certainty = 71.405151%
# Model: ModelEpoch5
# Prediction certainty = 77.474922%
# Model: ModelEpoch50
# Prediction certainty = 75.025551%
# Model: ModelEpoch55
# Prediction certainty = 79.934990%
# Model: ModelEpoch60
# Prediction certainty = 95.381424%
# Model: ModelEpoch65
# Prediction certainty = 82.506157%
# Model: ModelEpoch70
# Prediction certainty = 98.742798%
# Model: ModelEpoch75
# Prediction certainty = 99.127266%
# Model: ModelEpoch80
# Prediction certainty = 86.063522%
# Model: ModelEpoch85
# Prediction certainty = 72.018639%
# Model: ModelEpoch90
# Prediction certainty = 74.443558%
# Model: ModelEpoch95
# Prediction certainty = 72.057320%
