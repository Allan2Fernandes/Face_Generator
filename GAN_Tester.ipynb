# %%
import matplotlib
import tensorflow as tf
import os
import matplotlib.pyplot as plt
import numpy as np
# Out:
# c:\Users\allan\miniconda3\envs\tf2.9\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\Users\allan\miniconda3\envs\tf2.9\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# c:\Users\allan\miniconda3\envs\tf2.9\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
base_path = "Saved_models"
model_names = os.listdir(base_path)

# %%
model_paths = []
for model_name in model_names:
    path = os.path.join(base_path, model_name)
    model_paths.append(path)
    pass

# %%
models = []
for path in model_paths:
    model = tf.keras.models.load_model(path)
    models.append(model)
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
def display_image(image_array):
    image_array = image_array*0.5 + 0.5
    plt.imshow(image_array)
    plt.show()

# %%
for model, model_name in zip(models, model_names):
    generator, discriminator = model.layers
    prediction = 0
    generated_image = None
    while prediction < 0.7:
        noise = tf.random.normal(shape=(1, 128))
        generated_image = generator(noise)
        #display_image(generated_image[0])
        prediction = discriminator(generated_image)
        #print(prediction)
        pass
    print("Model: {}".format(model_name))
    print("Prediction certainty = {0:f}%".format(tf.get_static_value(prediction[0][0]*100)))
    display_image(generated_image[0])
# Out:
# Model: ModelEpoch10
# Prediction certainty = 79.268921%
# Model: ModelEpoch100
# Prediction certainty = 99.845757%
# Model: ModelEpoch105
# Prediction certainty = 70.416000%
# Model: ModelEpoch110
# Prediction certainty = 96.927383%
# Model: ModelEpoch115
# Prediction certainty = 81.861938%
# Model: ModelEpoch120
# Prediction certainty = 98.519859%
# Model: ModelEpoch125
# Prediction certainty = 96.374474%
# Model: ModelEpoch130
# Prediction certainty = 99.683640%
# Model: ModelEpoch135
# Prediction certainty = 80.685875%
# Model: ModelEpoch140
# Prediction certainty = 85.335999%
# Model: ModelEpoch145
# Prediction certainty = 78.768250%
# Model: ModelEpoch15
# Prediction certainty = 77.337601%
# Model: ModelEpoch150
# Prediction certainty = 75.667992%
# Model: ModelEpoch20
# Prediction certainty = 78.019188%
# Model: ModelEpoch25
# Prediction certainty = 77.946083%
# Model: ModelEpoch30
# Prediction certainty = 74.607727%
# Model: ModelEpoch35
# Prediction certainty = 85.555389%
# Model: ModelEpoch40
# Prediction certainty = 73.729050%
# Model: ModelEpoch45
# Prediction certainty = 84.008072%
# Model: ModelEpoch5
# Prediction certainty = 74.674980%
# Model: ModelEpoch50
# Prediction certainty = 76.001266%
# Model: ModelEpoch55
# Prediction certainty = 93.640884%
# Model: ModelEpoch60
# Prediction certainty = 72.076958%
# Model: ModelEpoch65
# Prediction certainty = 90.456543%
# Model: ModelEpoch70
# Prediction certainty = 96.087051%
# Model: ModelEpoch75
# Prediction certainty = 85.085968%
# Model: ModelEpoch80
# Prediction certainty = 79.476349%
# Model: ModelEpoch85
# Prediction certainty = 99.835266%
# Model: ModelEpoch90
# Prediction certainty = 77.988609%
# Model: ModelEpoch95
# Prediction certainty = 78.262009%
